# %%
from ultralytics.utils.benchmarks import benchmark
import torch

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"{'CUDA está disponible. Usando CUDA.' if torch.cuda.is_available() else 'CUDA no está disponible. Usando CPU.'}")

# Benchmark on GPU
benchmark(model="datasets/bioview-lizards_TRAIN/run/train/weights/best.pt",
          data="datasets/bioview-lizards_TRAIN/config.yaml",
          half=False,
          int8=True,
          device=device)
# Out:
# Setup complete ✅ (48 CPUs, 251.4 GB RAM, 1599.1/1758.3 GB disk)
#
# Benchmarks complete for best.pt on datasets/bioview-lizards_TRAIN/config.yaml at imgsz=160 (297.47s)
#                    Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)
# 0                 PyTorch       ✅        6.1               0.0364                    7.38
# 1             TorchScript       ✅       11.8               0.0379                    3.73
# 2                    ONNX       ✅       11.5               0.0379                    6.00
# 3                OpenVINO       ❌        0.0                  NaN                     NaN
# 4                TensorRT       ❎       12.7                  NaN                     NaN
# 5                  CoreML       ❌        0.0                  NaN                     NaN
# 6   TensorFlow SavedModel       ✅       38.2               0.0379                   30.67
# 7     TensorFlow GraphDef       ❌        0.0                  NaN                     NaN
# 8         TensorFlow Lite       ❌        0.0                  NaN                     NaN
# 9     TensorFlow Edge TPU       ❌        0.0                  NaN                     NaN
# 10          TensorFlow.js       ❌        0.0                  NaN                     NaN
# 11           PaddlePaddle       ✅       23.2               0.0379                   24.16
# 12                   NCNN       ✅       11.5               0.0379                    9.33
#                    Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)
# 0                 PyTorch       ✅        6.1               0.0364                    7.38
# 1             TorchScript       ✅       11.8               0.0379                    3.73
# 2                    ONNX       ✅       11.5               0.0379                    6.00
# 3                OpenVINO       ❌        0.0                  NaN                     NaN
# 4                TensorRT       ❎       12.7                  NaN                     NaN
# 5                  CoreML       ❌        0.0                  NaN                     NaN
# 6   TensorFlow SavedModel       ✅       38.2               0.0379                   30.67
# 7     TensorFlow GraphDef       ❌        0.0                  NaN                     NaN
# 8         TensorFlow Lite       ❌        0.0                  NaN                     NaN
# 9     TensorFlow Edge TPU       ❌        0.0                  NaN                     NaN
# 10          TensorFlow.js       ❌        0.0                  NaN                     NaN
# 11           PaddlePaddle       ✅       23.2               0.0379                   24.16
# 12                   NCNN       ✅       11.5               0.0379                    9.33
